# %%
from fastapi import FastAPI, HTTPException, Query
from pydantic import BaseModel

# %%
app = FastAPI()

@app.get("/")
def home():
    return {"message": "API Funcionando"}

# %%
import os
from mistralai import Mistral
from dotenv import load_dotenv

# %%
api_key = os.getenv("MISTRAL_API_KEY")
model = "mistral-small-2402"

client = Mistral(api_key=api_key)

chat_response = client.chat.complete(
    model= model,
    messages = [
        {
            "role": "user",
            "content": "What is the best option for calculating the KPI for a Call Center, give me some examples and formulas",
        },
    ]
)
print(chat_response.choices[0].message.content)
# Out:
# Sure, I'd be happy to help with that. Key Performance Indicators (KPIs) are crucial for measuring the performance of a call center. Here are some examples along with their formulas:
#
# 1. **Average Handle Time (AHT)**: This is the average duration of a call, including hold time and talk time. The formula is: AHT = (Total Handling Time) / (Number of Calls Handled)
#
# 2. **Service Level**: This measures the percentage of calls answered within a certain timeframe, usually 20-80 seconds. The formula is: Service Level (%) = (Number of Calls Answered within X seconds) / (Total Number of Calls) * 100
#
# 3. **First Call Resolution (FCR)**: This measures the percentage of calls resolved during the first interaction. The formula is: FCR (%) = (Number of Resolved Calls on First Contact) / (Total Number of Calls) * 100
#
# 4. **Customer Satisfaction (CSAT)**: This is usually measured through surveys. The formula is: CSAT (%) = (Number of Satisfied Customers) / (Total Number of Survey Responses) * 100
#
# 5. **Abandonment Rate**: This measures the percentage of callers who hang up before their call is answered. The formula is: Abandonment Rate (%) = (Number of Abandoned Calls) / (Total Number of Incoming Calls) * 100
