# %%
from fastapi import FastAPI, HTTPException, Query
from pydantic import BaseModel

# %%
app = FastAPI()

@app.get("/")
def home():
    return {"message": "API Funcionando"}

# %%
import os
from mistralai import Mistral
from dotenv import load_dotenv

# %%
api_key = os.getenv("MISTRAL_API_KEY")
model = "mistral-small-2402"

client = Mistral(api_key=api_key)

chat_response = client.chat.complete(
    model= model,
    messages = [
        {
            "role": "user",
            "content": "What is the best option for calculating the KPI for a Call Center, give me some examples and formulas",
        },
    ]
)
print(chat_response.choices[0].message.content)
# Out:
# Sure, I'd be happy to help with that. Key Performance Indicators (KPIs) are critical metrics used to measure the performance and efficiency of a call center. Here are some examples:
#
# 1. **Average Handle Time (AHT)**: This is the average duration of a transaction handled by an agent. The formula is: AHT = (Talk Time + Hold Time + After Call Work Time) / Number of Calls
#
# 2. **Service Level**: This is the percentage of calls answered within a specified target time. The formula is: Service Level = (Number of Calls Answered within Target Time / Total Number of Calls) x 100
#
# 3. **First Call Resolution (FCR)**: This measures the percentage of calls resolved on the first interaction with the customer. The formula is: FCR = (Number of Resolved Calls on First Contact / Total Number of Calls) x 100
#
# 4. **Customer Satisfaction (CSAT)**: This is usually measured through surveys and represents the percentage of customers who are satisfied with the service they received. The formula is: CSAT = (Number of Satisfied Customers / Total Number of Customers Surveyed) x 100
#
# 5. **Abandonment Rate**: This is the percentage of callers who hang up before their call is answered. The formula is: Abandonment Rate = (Number of Abandoned Calls / Total Number of Incoming Calls) x 100
